# %%
import jax.numpy as jnp
from jax.scipy import stats
from jax import random
# import numpy as np
from typing import *
import matplotlib.pyplot as plt
from abc import ABC

# %%
class JaxDistribution(ABC):
    def __call__(self, key):
        pass
    def pdf(self, x):
        pass
class Gaussian(JaxDistribution):
    def __init__(self, mu, sigma):
         self.mu = mu
         self.sigma = sigma
    def __call__(self, key):
        return random.normal(key)*self.sigma + self.mu
    def pdf(x):
        return stats.norm.pdf(  )

# %%
def MH(p: JaxDistribution, q: JaxDistribution, t_max: int = 10000):
    key = random.PRNGKey(0)
    key, skey = random.split(key)
    state = q(skey)
    t = 0
    while t < t_max:
        key, skey = random.split(key)
        x_tilde = q_sample(skey)
        alpha = (p(x_tilde) * (q())/()
    return samples

# %%
MH()

# %%
key = random.PRNGKey(0)
x = random.normal
samples = jnp.linspace(-10, 10, 50)
plt.plot(samples, stats.norm.pdf(samples, 0, jnp.sqrt(0.2)))

# %%
import scipy.io as sio

# %%
f = sio.loadmat("simData_L=0.75_d=2.mat")

# %%
f
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Thu Apr  9 15:59:51 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'lambda': array([[0.75]]),
#  'N': array([[400]], dtype=uint16),
#  'psi0': array([[0.70710678],
#         [0.        ],
#         [0.        ],
#         [0.70710678]]),
#  'M': array([[ 0.25+0.j  , -0.25+0.j  , -0.25+0.j  ,  0.25+0.j  , -0.25+0.j  ,
#           0.25+0.j  ,  0.25+0.j  , -0.25+0.j  , -0.25+0.j  ,  0.25+0.j  ,
#           0.25+0.j  , -0.25+0.j  ,  0.25+0.j  , -0.25+0.j  , -0.25+0.j  ,
#           0.25+0.j  ],
#         [ 0.25+0.j  ,  0.25+0.j  , -0.25+0.j  , -0.25+0.j  ,  0.25+0.j  ,
#           0.25+0.j  , -0.25+0.j  , -0.25+0.j  , -0.25+0.j  , -0.25+0.j  ,
#           0.25+0.j  ,  0.25+0.j  , -0.25+0.j  , -0.25+0.j  ,  0.25+0.j  ,
#           0.25+0.j  ],
#         [ 0.25+0.j  , -0.25+0.j  ,  0.25+0.j  , -0.25+0.j  , -0.25+0.j  ,
#           0.25+0.j  , -0.25+0.j  ,  0.25+0.j  ,  0.25+0.j  , -0.25+0.j  ,
# ...
